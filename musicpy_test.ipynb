# %%
from musicpy.daw import *

# %%
new_song = daw(3, name='my first song')
print(new_song)
# Out:
# [daw] my first song
# Channel 1 | not loaded
# Channel 2 | not loaded
# Channel 3 | not loaded

# %%
new_song.load(0, 'sounds/custom_tone')
print(new_song)
# Out:
# [daw] my first song
# Channel 1 | sounds/custom_tone
# Channel 2 | not loaded
# Channel 3 | not loaded

# %%
guitar = (C('CM7', 3, 1/4, 1/8)^2 |
          C('G7sus', 2, 1/4, 1/8)^2 |
          C('A7sus', 2, 1/4, 1/8)^2 |
          C('Em7', 2, 1/4, 1/8)^2 | 
          C('FM7', 2, 1/4, 1/8)^2 |
          C('CM7', 3, 1/4, 1/8)@1 |
          C('AbM7', 2, 1/4, 1/8)^2 |
          C('G7sus', 2, 1/4, 1/8)^2) * 2

play(guitar, bpm=100, instrument=25)

# %%
|
