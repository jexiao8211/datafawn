# %%
import importlib
import torch

from pathlib import Path
import datafawn

importlib.reload(datafawn)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device('cpu')
    print("CUDA not available, using CPU")

# %% [markdown]
# # Download Videos From YouTube

# %%
# Download Videos From YouTube
import yt_dlp
from pathlib import Path

# Create output directory if it doesn't exist
output_dir = Path("data/raw_videos")

urls = [
    'https://youtu.be/RZlvWpeC208?si=OyoDhWobmJUvrhh9',
    'https://www.youtube.com/watch?v=CoL8Gtvxfl0',
    'https://www.youtube.com/watch?v=WrR3fVQ3W3s',
    'https://www.youtube.com/watch?v=WskPDhUJ_Ho',
    'https://www.youtube.com/watch?v=vE2VloljDio',
]

# Base yt-dlp options (shared across all downloads)
base_opts = {
    'format': 'bestvideo[ext=mp4]+bestaudio[ext=m4a]/best[ext=mp4]/best',  # Prefer mp4
    'noplaylist': True,  # Download only single video, not playlist
}

for i, url in enumerate(urls):
    # Create options dict for this specific video
    ydl_opts = {
        **base_opts,
        'outtmpl': str(output_dir / f'video{i}.%(ext)s'),  # Output template
    }
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading video {i} from {url}...")
            ydl.download([url])
            print(f"Successfully downloaded video {i}")
        except Exception as e:
            print(f"Error downloading video {i}: {e}")
# Out:
# Downloading video 0 from https://youtu.be/RZlvWpeC208?si=OyoDhWobmJUvrhh9...
# [youtube] Extracting URL: https://youtu.be/RZlvWpeC208?si=OyoDhWobmJUvrhh9
# [youtube] RZlvWpeC208: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] RZlvWpeC208: Downloading android sdkless player API JSON
# [youtube] RZlvWpeC208: Downloading web safari player API JSON
# WARNING: [youtube] RZlvWpeC208: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] RZlvWpeC208: Downloading m3u8 information
# WARNING: [youtube] RZlvWpeC208: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] RZlvWpeC208: Downloading 1 format(s): 399+140
# [download] Destination: data\raw_videos\video0.f399.mp4
# [download] 100% of    1.09MiB in 00:00:00 at 6.98MiB/s
# [download] Destination: data\raw_videos\video0.f140.m4a
# [download] 100% of  139.84KiB in 00:00:00 at 1.57MiB/s
# [Merger] Merging formats into "data\raw_videos\video0.mp4"
# Deleting original file data\raw_videos\video0.f140.m4a (pass -k to keep)
# Deleting original file data\raw_videos\video0.f399.mp4 (pass -k to keep)
# Successfully downloaded video 0
# Downloading video 1 from https://www.youtube.com/watch?v=CoL8Gtvxfl0...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CoL8Gtvxfl0
# [youtube] CoL8Gtvxfl0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] CoL8Gtvxfl0: Downloading android sdkless player API JSON
# [youtube] CoL8Gtvxfl0: Downloading web safari player API JSON
# WARNING: [youtube] CoL8Gtvxfl0: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] CoL8Gtvxfl0: Downloading m3u8 information
# WARNING: [youtube] CoL8Gtvxfl0: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] CoL8Gtvxfl0: Downloading 1 format(s): 396+140
# [download] Destination: data\raw_videos\video1.f396.mp4
# [download] 100% of  478.37KiB in 00:00:00 at 2.12MiB/s
# [download] Destination: data\raw_videos\video1.f140.m4a
# [download] 100% of  527.43KiB in 00:00:00 at 4.21MiB/s
# [Merger] Merging formats into "data\raw_videos\video1.mp4"
# Deleting original file data\raw_videos\video1.f140.m4a (pass -k to keep)
# Deleting original file data\raw_videos\video1.f396.mp4 (pass -k to keep)
# [FixupStretched] Fixing aspect ratio of "data\raw_videos\video1.mp4"
# Successfully downloaded video 1
# Downloading video 2 from https://www.youtube.com/watch?v=WrR3fVQ3W3s...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WrR3fVQ3W3s
# [youtube] WrR3fVQ3W3s: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] WrR3fVQ3W3s: Downloading android sdkless player API JSON
# [youtube] WrR3fVQ3W3s: Downloading web safari player API JSON
# WARNING: [youtube] WrR3fVQ3W3s: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] WrR3fVQ3W3s: Downloading m3u8 information
# WARNING: [youtube] WrR3fVQ3W3s: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] WrR3fVQ3W3s: Downloading 1 format(s): 135+140
# [download] Destination: data\raw_videos\video2.f135.mp4
# [download] 100% of    1.12MiB in 00:00:00 at 2.60MiB/s
# [download] Destination: data\raw_videos\video2.f140.m4a
# [download] 100% of  458.01KiB in 00:00:00 at 3.24MiB/s
# [Merger] Merging formats into "data\raw_videos\video2.mp4"
# Deleting original file data\raw_videos\video2.f135.mp4 (pass -k to keep)
# Deleting original file data\raw_videos\video2.f140.m4a (pass -k to keep)
# Successfully downloaded video 2
# Downloading video 3 from https://www.youtube.com/watch?v=WskPDhUJ_Ho...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WskPDhUJ_Ho
# [youtube] WskPDhUJ_Ho: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] WskPDhUJ_Ho: Downloading android sdkless player API JSON
# [youtube] WskPDhUJ_Ho: Downloading web safari player API JSON
# WARNING: [youtube] WskPDhUJ_Ho: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] WskPDhUJ_Ho: Downloading m3u8 information
# WARNING: [youtube] WskPDhUJ_Ho: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] WskPDhUJ_Ho: Downloading 1 format(s): 135+140
# [download] Destination: data\raw_videos\video3.f135.mp4
# [download] 100% of  981.47KiB in 00:00:00 at 2.38MiB/s
# [download] Destination: data\raw_videos\video3.f140.m4a
# [download] 100% of  153.04KiB in 00:00:00 at 1.56MiB/s
# [Merger] Merging formats into "data\raw_videos\video3.mp4"
# Deleting original file data\raw_videos\video3.f135.mp4 (pass -k to keep)
# Deleting original file data\raw_videos\video3.f140.m4a (pass -k to keep)
# Successfully downloaded video 3
# Downloading video 4 from https://www.youtube.com/watch?v=vE2VloljDio...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vE2VloljDio
# [youtube] vE2VloljDio: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] vE2VloljDio: Downloading android sdkless player API JSON
# [youtube] vE2VloljDio: Downloading web safari player API JSON
# WARNING: [youtube] vE2VloljDio: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] vE2VloljDio: Downloading m3u8 information
# WARNING: [youtube] vE2VloljDio: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] vE2VloljDio: Downloading 1 format(s): 299+140
# [download] Destination: data\raw_videos\video4.f299.mp4
# [download] 100% of   10.81MiB in 00:00:00 at 16.97MiB/s
# [download] Destination: data\raw_videos\video4.f140.m4a
# [download] 100% of  240.80KiB in 00:00:00 at 2.72MiB/s
# [Merger] Merging formats into "data\raw_videos\video4.mp4"
# Deleting original file data\raw_videos\video4.f140.m4a (pass -k to keep)
# Deleting original file data\raw_videos\video4.f299.mp4 (pass -k to keep)
# Successfully downloaded video 4

# %%
# Load the .mp4's back in
import cv2

cap = cv2.VideoCapture("video.mp4")

# %% [markdown]
# # Run Entire pipeline on all videos

# %% [markdown]
# ## Define Pipeline

# %%
import datafawn
import torch

if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device('cpu')
    print("CUDA not available, using CPU")
# Out:
# Using GPU: NVIDIA GeForce RTX 5070 Ti Laptop GPU

# %%
# =============== POSE ESTIMATORS =============== #
dlc_estimator = datafawn.DeepLabCutPoseEstimator(
    model_name='superanimal_quadruped',
    detector_name='fasterrcnn_resnet50_fpn_v2',
    hrnet_model='hrnet_w32',
    max_individuals=1,
    pcutoff=0.15,
    dest_folder='data/pose_estimates/test_batch',
    # dest_folder='data_example/pose_estimates/churchdeer',
    device=device
)

# =============== POSTPROCESSORS =============== #
paws = ['front_left_paw', 'front_right_paw', 'back_left_paw', 'back_right_paw']
rel_paws = ['front_left_paw_rel', 'front_right_paw_rel', 'back_left_paw_rel', 'back_right_paw_rel']

reference_map = {
    'back_base': ['front_left_paw', 'front_right_paw'],
    'tail_base': ['back_left_paw', 'back_right_paw']
}

rel_pp = datafawn.RelativePawPositionPostprocessor()

error_pp = datafawn.ErrorPostprocessor(
    bodyparts=rel_paws,
    use_velocity=True,
    use_likelihood=True,
    use_distance=True,
    velocity_kwargs={'threshold_pixels': 50, 'window_size': 5},
    likelihood_kwargs={'min_likelihood': 0.5},
    distance_kwargs={'reference_map': reference_map, 'max_distance': 300}
    )



# =============== EVENT EXTRACTORS =============== #
zeni_extractor = datafawn.ZeniExtractor(
    smooth_window_size=5,
    prominence_percentage=0.08,
    orientation_likelihood_threshold=0.0,
    orientation_smooth_window_size=15,
    show_plots=True
)

# Create pipeline
pipeline = datafawn.EventDetectionPipeline(
    pose_estimator=dlc_estimator,
    postprocessors=[rel_pp, error_pp],
    event_extractors=[zeni_extractor]
)

# %% [markdown]
# ## Run pipeline

# %%
raw_vid_dir = Path("data/raw_videos")
raw_videos = list(raw_vid_dir.glob("*.mp4"))
print(raw_videos)

results = []
for video in raw_videos:
    result = pipeline.run(
        video_path=video,
        pose_data_path=None
    )
    results.append(result)
# Out:
# [WindowsPath('data/raw_videos/video0.mp4'), WindowsPath('data/raw_videos/video1.mp4'), WindowsPath('data/raw_videos/video2.mp4'), WindowsPath('data/raw_videos/video3.mp4'), WindowsPath('data/raw_videos/video4.mp4')]
# Running video inference on [WindowsPath('data/raw_videos/video0.mp4')] with superanimal_quadruped_hrnet_w32
# Using pytorch for model hrnet_w32
# Processing video data\raw_videos\video0.mp4
# Starting to analyze data\raw_videos\video0.mp4
# Video metadata:
#   Overall # of frames:    262
#   Duration of video [s]:  8.73
#   fps:                    30.0
#   resolution:             w=1916, h=1080
#
# Running detector with batch size 1
# 100%|██████████| 262/262 [00:20<00:00, 12.58it/s]
# Running pose prediction with batch size 1
# 100%|██████████| 262/262 [00:13<00:00, 19.88it/s]
# WARNING:root:The video metadata indicates that there 262 in the video, but only 236 were able to be processed. This can happen if the video is corrupted. You can try to fix the issue by re-encoding your video (tips on how to do that: https://deeplabcut.github.io/DeepLabCut/docs/recipes/io.html#tips-on-video-re-encoding-and-preprocessing)
# Saving results to data/pose_estimates/test_batch
# Saving results in data\pose_estimates\test_batch\video0_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2_.h5 and data\pose_estimates\test_batch\video0_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__full.pickle
# c:\Users\jexia\anaconda3\envs\DEEPLABCUT\Lib\site-packages\deeplabcut\utils\make_labeled_video.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Dataframe.groupby(level="individuals", axis=1).size().values // 3
# Duration of video [s]: 8.73, recorded with 30.0 fps!
# Overall # of frames: 262 with cropped frame dimensions: 1916 1080
# Generating frames and creating video.
# 100%|██████████| 236/236 [00:08<00:00, 27.53it/s]
# Video with predictions was saved as data\pose_estimates\test_batch
# Dataframe with relative positions created:
# Original shape: (236, 117)
# New shape: (236, 129)
#
# New bodyparts added:
# ['back_left_paw_rel', 'back_right_paw_rel', 'front_left_paw_rel', 'front_right_paw_rel']
# Running video inference on [WindowsPath('data/raw_videos/video1.mp4')] with superanimal_quadruped_hrnet_w32
# Using pytorch for model hrnet_w32
# Processing video data\raw_videos\video1.mp4
# Starting to analyze data\raw_videos\video1.mp4
# Video metadata:
#   Overall # of frames:    791
#   Duration of video [s]:  32.96
#   fps:                    24.0
#   resolution:             w=640, h=360
#
# Running detector with batch size 1
# 100%|██████████| 791/791 [00:55<00:00, 14.30it/s]
# Running pose prediction with batch size 1
# 100%|██████████| 791/791 [00:39<00:00, 20.04it/s]
# Saving results to data/pose_estimates/test_batch
# Saving results in data\pose_estimates\test_batch\video1_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2_.h5 and data\pose_estimates\test_batch\video1_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__full.pickle
# Duration of video [s]: 32.96, recorded with 24.0 fps!
# Overall # of frames: 791 with cropped frame dimensions: 640 360
# Generating frames and creating video.
# c:\Users\jexia\anaconda3\envs\DEEPLABCUT\Lib\site-packages\deeplabcut\utils\make_labeled_video.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Dataframe.groupby(level="individuals", axis=1).size().values // 3
# 100%|██████████| 791/791 [00:08<00:00, 92.96it/s]
# Video with predictions was saved as data\pose_estimates\test_batch
# Dataframe with relative positions created:
# Original shape: (791, 117)
# New shape: (791, 129)
#
# New bodyparts added:
# ['back_left_paw_rel', 'back_right_paw_rel', 'front_left_paw_rel', 'front_right_paw_rel']
# Running video inference on [WindowsPath('data/raw_videos/video2.mp4')] with superanimal_quadruped_hrnet_w32
# Using pytorch for model hrnet_w32
# Processing video data\raw_videos\video2.mp4
# Starting to analyze data\raw_videos\video2.mp4
# Video metadata:
#   Overall # of frames:    721
#   Duration of video [s]:  28.84
#   fps:                    25.0
#   resolution:             w=666, h=480
#
# Running detector with batch size 1
# 100%|██████████| 721/721 [00:46<00:00, 15.59it/s]
# Running pose prediction with batch size 1
# 100%|██████████| 721/721 [00:32<00:00, 21.87it/s]
# Saving results to data/pose_estimates/test_batch
# Saving results in data\pose_estimates\test_batch\video2_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2_.h5 and data\pose_estimates\test_batch\video2_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__full.pickle
# Duration of video [s]: 28.84, recorded with 25.0 fps!
# Overall # of frames: 721 with cropped frame dimensions: 666 480
# Generating frames and creating video.
# c:\Users\jexia\anaconda3\envs\DEEPLABCUT\Lib\site-packages\deeplabcut\utils\make_labeled_video.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Dataframe.groupby(level="individuals", axis=1).size().values // 3
# 100%|██████████| 721/721 [00:05<00:00, 130.38it/s]
# Video with predictions was saved as data\pose_estimates\test_batch
# Dataframe with relative positions created:
# Original shape: (721, 117)
# New shape: (721, 129)
#
# New bodyparts added:
# ['back_left_paw_rel', 'back_right_paw_rel', 'front_left_paw_rel', 'front_right_paw_rel']
# Running video inference on [WindowsPath('data/raw_videos/video3.mp4')] with superanimal_quadruped_hrnet_w32
# Using pytorch for model hrnet_w32
# Processing video data\raw_videos\video3.mp4
# Starting to analyze data\raw_videos\video3.mp4
# Video metadata:
#   Overall # of frames:    285
#   Duration of video [s]:  9.50
#   fps:                    30.0
#   resolution:             w=640, h=480
#
# Running detector with batch size 1
# 100%|██████████| 285/285 [00:17<00:00, 15.91it/s]
# Running pose prediction with batch size 1
# 100%|██████████| 285/285 [00:11<00:00, 25.76it/s]
# c:\Users\jexia\anaconda3\envs\DEEPLABCUT\Lib\site-packages\deeplabcut\utils\make_labeled_video.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Dataframe.groupby(level="individuals", axis=1).size().values // 3
# Saving results to data/pose_estimates/test_batch
# Saving results in data\pose_estimates\test_batch\video3_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2_.h5 and data\pose_estimates\test_batch\video3_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__full.pickle
# Duration of video [s]: 9.5, recorded with 30.0 fps!
# Overall # of frames: 285 with cropped frame dimensions: 640 480
# Generating frames and creating video.
# 100%|██████████| 285/285 [00:01<00:00, 156.70it/s]
# Video with predictions was saved as data\pose_estimates\test_batch
# Dataframe with relative positions created:
# Original shape: (285, 117)
# New shape: (285, 129)
#
# New bodyparts added:
# ['back_left_paw_rel', 'back_right_paw_rel', 'front_left_paw_rel', 'front_right_paw_rel']
# Running video inference on [WindowsPath('data/raw_videos/video4.mp4')] with superanimal_quadruped_hrnet_w32
# Using pytorch for model hrnet_w32
# Processing video data\raw_videos\video4.mp4
# Starting to analyze data\raw_videos\video4.mp4
# Video metadata:
#   Overall # of frames:    908
#   Duration of video [s]:  15.13
#   fps:                    60.0
#   resolution:             w=1920, h=1080
#
# Running detector with batch size 1
# 100%|██████████| 908/908 [01:03<00:00, 14.25it/s]
# Running pose prediction with batch size 1
# 100%|██████████| 908/908 [00:43<00:00, 20.79it/s]
# Saving results to data/pose_estimates/test_batch
# Saving results in data\pose_estimates\test_batch\video4_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2_.h5 and data\pose_estimates\test_batch\video4_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__full.pickle
# c:\Users\jexia\anaconda3\envs\DEEPLABCUT\Lib\site-packages\deeplabcut\utils\make_labeled_video.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Dataframe.groupby(level="individuals", axis=1).size().values // 3
# Duration of video [s]: 15.13, recorded with 60.0 fps!
# Overall # of frames: 908 with cropped frame dimensions: 1920 1080
# Generating frames and creating video.
# 100%|██████████| 908/908 [00:25<00:00, 35.09it/s]
# Video with predictions was saved as data\pose_estimates\test_batch
# Dataframe with relative positions created:
# Original shape: (908, 117)
# New shape: (908, 129)
#
# New bodyparts added:
# ['back_left_paw_rel', 'back_right_paw_rel', 'front_left_paw_rel', 'front_right_paw_rel']

# %% [markdown]
# ## Generate soundscapes for each output

# %%
from add_sounds_to_video import add_sounds_for_all_paws

import importlib
import add_sounds_to_video

importlib.reload(add_sounds_to_video)
# Out:
# <module 'add_sounds_to_video' from 'c:\\Users\\jexia\\OneDrive\\Documents\\projects\\datafawn\\add_sounds_to_video.py'>

# %%
#  Define different sounds for each paw
paw_sound_map = {
    'front_left_paw_rel': 'data_example/sounds/22415__anthousai__wind-chimes/398494__anthousai__wind-chimes-single-01.wav',
    'front_right_paw_rel': 'data_example/sounds/22415__anthousai__wind-chimes/398493__anthousai__wind-chimes-single-02.wav',
    'back_left_paw_rel': 'data_example/sounds/22415__anthousai__wind-chimes/398492__anthousai__wind-chimes-single-03.wav',
    'back_right_paw_rel': 'data_example/sounds/22415__anthousai__wind-chimes/398496__anthousai__wind-chimes-single-04.wav'
}


for i, result in enumerate(results):
    strikes_parsed = result['events']['zeni']['strikes'][('superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2_', 'animal0')]

    pose_est_video_path = f'data/pose_estimates/test_batch/video{i}_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__labeled_before_adapt.mp4'

    # Add all sounds to video at once
    output_path = add_sounds_for_all_paws(
        video_path=pose_est_video_path, # raw video
        # video_path=POSE_EST_VIDEO_PATH, # video with pose estimation added
        strikes_dict=strikes_parsed,  
        paw_sound_map=paw_sound_map,
        # output_path = 'data_example/soundscape_vids/churchdeer.mp4',
        output_path = f'data/soundscape_vids/test_batch/video{i}.mp4',
        )
# Out:
# Loading video: data\pose_estimates\test_batch\video0_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__labeled_before_adapt.mp4
# Video FPS: 30.0
# Video duration: 7.87 seconds
#
# Processing front_left_paw_rel:
#   Found 8 strikes
#   Strike timestamps: ['1.13s', '1.77s', '2.23s']...
#   Sound duration: 5.00 seconds
#   Created 8 audio clips for front_left_paw_rel
#
# Processing front_right_paw_rel:
#   Found 4 strikes
#   Strike timestamps: ['1.27s', '4.23s', '6.53s']...
#   Sound duration: 3.16 seconds
#   Created 4 audio clips for front_right_paw_rel
#
# Processing back_left_paw_rel:
#   Found 5 strikes
#   Strike timestamps: ['0.97s', '6.50s', '6.80s']...
#   Sound duration: 3.19 seconds
#   Created 5 audio clips for back_left_paw_rel
#
# Processing back_right_paw_rel:
#   Found 4 strikes
#   Strike timestamps: ['6.10s', '6.50s', '6.80s']...
#   Sound duration: 4.04 seconds
# frame_index:   1%|          | 2/236 [00:50<1:38:29, 25.25s/it, now=None]
#   Created 4 audio clips for back_right_paw_rel
#
# Total audio clips created: 21
#
# Writing output video to: data\soundscape_vids\test_batch\video0.mp4
# MoviePy - Building video data\soundscape_vids\test_batch\video0.mp4.
# MoviePy - Writing audio in video0TEMP_MPY_wvf_snd.mp4
# frame_index:   1%|          | 2/236 [00:50<1:38:59, 25.38s/it, now=None]
# MoviePy - Done.
# MoviePy - Writing video data\soundscape_vids\test_batch\video0.mp4
# frame_index:   1%|          | 2/236 [00:54<1:46:57, 27.42s/it, now=None]
# MoviePy - Done !
# MoviePy - video ready data\soundscape_vids\test_batch\video0.mp4
# Done! Output saved to: data\soundscape_vids\test_batch\video0.mp4
# Loading video: data\pose_estimates\test_batch\video1_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__labeled_before_adapt.mp4
# Video FPS: 24.0
# Video duration: 32.96 seconds
#
# Processing front_left_paw_rel:
#   Found 11 strikes
#   Strike timestamps: ['1.50s', '3.67s', '6.08s']...
#   Sound duration: 5.00 seconds
#   Created 11 audio clips for front_left_paw_rel
#
# Processing front_right_paw_rel:
#   Found 13 strikes
#   Strike timestamps: ['1.75s', '3.92s', '6.33s']...
#   Sound duration: 3.16 seconds
#   Created 13 audio clips for front_right_paw_rel
#
# Processing back_left_paw_rel:
#   Found 15 strikes
#   Strike timestamps: ['0.67s', '1.29s', '2.75s']...
#   Sound duration: 3.19 seconds
#   Created 15 audio clips for back_left_paw_rel
#
# Processing back_right_paw_rel:
#   Found 14 strikes
#   Strike timestamps: ['0.83s', '2.62s', '4.88s']...
#   Sound duration: 4.04 seconds
# frame_index:   1%|          | 2/236 [01:00<1:58:46, 30.46s/it, now=None]
#   Created 14 audio clips for back_right_paw_rel
#
# Total audio clips created: 53
#
# Writing output video to: data\soundscape_vids\test_batch\video1.mp4
# MoviePy - Building video data\soundscape_vids\test_batch\video1.mp4.
# MoviePy - Writing audio in video1TEMP_MPY_wvf_snd.mp4
# frame_index:   1%|          | 2/236 [01:01<2:00:45, 30.96s/it, now=None]
# MoviePy - Done.
# MoviePy - Writing video data\soundscape_vids\test_batch\video1.mp4
# frame_index:   1%|          | 2/236 [01:03<2:03:57, 31.78s/it, now=None]
# MoviePy - Done !
# MoviePy - video ready data\soundscape_vids\test_batch\video1.mp4
# Done! Output saved to: data\soundscape_vids\test_batch\video1.mp4
# Loading video: data\pose_estimates\test_batch\video2_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__labeled_before_adapt.mp4
# Video FPS: 25.0
# Video duration: 28.84 seconds
#
# Processing front_left_paw_rel:
#   Found 45 strikes
#   Strike timestamps: ['0.80s', '1.92s', '3.04s']...
#   Sound duration: 5.00 seconds
#   Created 45 audio clips for front_left_paw_rel
#
# Processing front_right_paw_rel:
#   Found 46 strikes
#   Strike timestamps: ['0.20s', '1.32s', '2.44s']...
#   Sound duration: 3.16 seconds
#   Created 46 audio clips for front_right_paw_rel
#
# Processing back_left_paw_rel:
#   Found 45 strikes
#   Strike timestamps: ['0.72s', '1.84s', '2.40s']...
#   Sound duration: 3.19 seconds
#   Created 45 audio clips for back_left_paw_rel
#
# Processing back_right_paw_rel:
#   Found 43 strikes
#   Strike timestamps: ['1.24s', '2.32s', '3.44s']...
#   Sound duration: 4.04 seconds
# frame_index:   1%|          | 2/236 [01:22<2:40:23, 41.12s/it, now=None]
#   Created 43 audio clips for back_right_paw_rel
#
# Total audio clips created: 179
#
# Writing output video to: data\soundscape_vids\test_batch\video2.mp4
# MoviePy - Building video data\soundscape_vids\test_batch\video2.mp4.
# MoviePy - Writing audio in video2TEMP_MPY_wvf_snd.mp4
# frame_index:   1%|          | 2/236 [01:25<2:46:28, 42.69s/it, now=None]
# MoviePy - Done.
# MoviePy - Writing video data\soundscape_vids\test_batch\video2.mp4
# frame_index:   1%|          | 2/236 [01:26<2:48:45, 43.27s/it, now=None]
# MoviePy - Done !
# MoviePy - video ready data\soundscape_vids\test_batch\video2.mp4
# Done! Output saved to: data\soundscape_vids\test_batch\video2.mp4
# Loading video: data\pose_estimates\test_batch\video3_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__labeled_before_adapt.mp4
# Video FPS: 30.0
# Video duration: 9.50 seconds
#
# Processing front_left_paw_rel:
#   Found 13 strikes
#   Strike timestamps: ['0.47s', '0.83s', '1.33s']...
#   Sound duration: 5.00 seconds
#   Created 13 audio clips for front_left_paw_rel
#
# Processing front_right_paw_rel:
#   Found 13 strikes
#   Strike timestamps: ['0.50s', '1.03s', '1.43s']...
#   Sound duration: 3.16 seconds
#   Created 13 audio clips for front_right_paw_rel
#
# Processing back_left_paw_rel:
#   Found 15 strikes
#   Strike timestamps: ['0.27s', '0.70s', '1.17s']...
#   Sound duration: 3.19 seconds
#   Created 15 audio clips for back_left_paw_rel
#
# Processing back_right_paw_rel:
#   Found 14 strikes
#   Strike timestamps: ['0.20s', '0.63s', '1.10s']...
#   Sound duration: 4.04 seconds
# frame_index:   1%|          | 2/236 [01:32<3:00:40, 46.32s/it, now=None]
#   Created 14 audio clips for back_right_paw_rel
#
# Total audio clips created: 55
#
# Writing output video to: data\soundscape_vids\test_batch\video3.mp4
# MoviePy - Building video data\soundscape_vids\test_batch\video3.mp4.
# MoviePy - Writing audio in video3TEMP_MPY_wvf_snd.mp4
# frame_index:   1%|          | 2/236 [01:33<3:02:06, 46.69s/it, now=None]
# MoviePy - Done.
# MoviePy - Writing video data\soundscape_vids\test_batch\video3.mp4
# frame_index:   1%|          | 2/236 [01:34<3:03:40, 47.09s/it, now=None]
# MoviePy - Done !
# MoviePy - video ready data\soundscape_vids\test_batch\video3.mp4
# Done! Output saved to: data\soundscape_vids\test_batch\video3.mp4
# Loading video: data\pose_estimates\test_batch\video4_superanimal_quadruped_hrnet_w32_fasterrcnn_resnet50_fpn_v2__labeled_before_adapt.mp4
# Video FPS: 60.0
# Video duration: 15.13 seconds
#
# Processing front_left_paw_rel:
#   Found 17 strikes
#   Strike timestamps: ['5.23s', '6.52s', '7.22s']...
#   Sound duration: 5.00 seconds
#   Created 17 audio clips for front_left_paw_rel
#
# Processing front_right_paw_rel:
#   Found 15 strikes
#   Strike timestamps: ['4.58s', '5.95s', '6.92s']...
#   Sound duration: 3.16 seconds
#   Created 15 audio clips for front_right_paw_rel
#
# Processing back_left_paw_rel:
#   Found 18 strikes
#   Strike timestamps: ['3.65s', '4.78s', '5.45s']...
#   Sound duration: 3.19 seconds
#   Created 18 audio clips for back_left_paw_rel
#
# Processing back_right_paw_rel:
#   Found 17 strikes
#   Strike timestamps: ['3.62s', '3.92s', '5.50s']...
#   Sound duration: 4.04 seconds
# frame_index:   1%|          | 2/236 [01:41<3:18:40, 50.94s/it, now=None]
#   Created 17 audio clips for back_right_paw_rel
#
# Total audio clips created: 67
#
# Writing output video to: data\soundscape_vids\test_batch\video4.mp4
# MoviePy - Building video data\soundscape_vids\test_batch\video4.mp4.
# MoviePy - Writing audio in video4TEMP_MPY_wvf_snd.mp4
# frame_index:   1%|          | 2/236 [01:42<3:20:31, 51.42s/it, now=None]
# MoviePy - Done.
# MoviePy - Writing video data\soundscape_vids\test_batch\video4.mp4
# frame_index:   1%|          | 2/236 [01:56<3:46:30, 58.08s/it, now=None]
# MoviePy - Done !
# MoviePy - video ready data\soundscape_vids\test_batch\video4.mp4
# Done! Output saved to: data\soundscape_vids\test_batch\video4.mp4
